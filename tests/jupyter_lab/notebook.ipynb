# %% [markdown]
# # Lab Test Notebook
#
# A simple notebook used to verify `jupyter_lab` targets build correctly.

# %%
print("Hello from jupyter_lab!")
import time

# %%
print("hi")
time.sleep(2)

# %%
print("hi")
time.sleep(2)

# %%
print("hi")
time.sleep(2)

# %%
print("hi")
time.sleep(2)

# %%
print("hi")
time.sleep(2)

# %%
print("hi")
time.sleep(2)

# %%
print("hi")
time.sleep(2)

# %%
print("hi")
time.sleep(2)

# %%
result = sum(range(10))
print(f"Sum of 0..9 = {result}")
assert result == 45
