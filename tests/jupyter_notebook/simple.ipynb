# %% [markdown]
# # Simple Notebook Test
#
# This is a simple notebook for testing the `jupyter_notebook` rule.

# %%
# Simple computation
x = 1 + 1
print(f"1 + 1 = {x}")
assert x == 2

# %%
# List comprehension
squares = [i**2 for i in range(5)]
print(f"Squares: {squares}")
assert squares == [0, 1, 4, 9, 16]
